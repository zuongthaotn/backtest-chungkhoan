# %% [markdown]
# # MACD - Strategy - Backtesting

# %% [markdown]
# ### Import Library

# %%
import warnings
warnings.filterwarnings('ignore')
#
import numpy as np
import pandas as pd
import numpy as np
import pandas_ta as ta
from backtesting.backtesting import Backtest, Strategy
# from backtesting._plotting import set_bokeh_output
# set_bokeh_output(notebook=False)

import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [12, 6]
plt.rcParams['figure.dpi'] = 120

# %% [markdown]
# ### Load Price Data

# %%
import os
from pathlib import Path
notebook_path = os.getcwd()
algo_dir = Path(notebook_path).parent.parent
csv_file = str(algo_dir) + '/vn-stock-data/VN30ps/VN30F1M_5minutes.csv'
is_file = os.path.isfile(csv_file)
if is_file:
    dataset = pd.read_csv(csv_file, index_col='Date', parse_dates=True)
else:
    print('remote')
    dataset = pd.read_csv("https://raw.githubusercontent.com/zuongthaotn/vn-stock-data/main/VN30ps/VN30F1M_5minutes.csv", index_col='Date', parse_dates=True)

# %%
data = dataset.copy()

# %%
data = data[data.index > '2020-11-01 00:00:00']
# data = data[(data.index > '2020-11-01 00:00:00') & (data.index < '2024-10-01 00:00:00')]
# data = data[data.index > '2024-11-01 00:00:00']

# %%
data
# Out:
#                        Open    High     Low   Close  Volume
# Date
# 2020-11-02 09:00:00   900.1   900.2   899.3   900.1    1910
# 2020-11-02 09:05:00   900.2   900.2   898.7   899.4    1670
# 2020-11-02 09:10:00   899.5   900.0   899.0   899.5    1329
# 2020-11-02 09:15:00   899.4   899.5   898.2   898.6    1722
# 2020-11-02 09:20:00   898.5   898.6   896.5   898.2    2939
# ...                     ...     ...     ...     ...     ...
# 2025-11-04 14:10:00  1890.7  1891.0  1885.5  1887.3    5379
# 2025-11-04 14:15:00  1887.2  1899.0  1887.2  1898.5   13871
# 2025-11-04 14:20:00  1898.2  1907.7  1897.0  1904.2   16090
# 2025-11-04 14:25:00  1904.1  1907.4  1900.3  1902.7    9901
# 2025-11-04 14:45:00  1898.0  1898.0  1898.0  1898.0    6043
#
# [63446 rows x 5 columns]

# %%
def cal_signal(r):
    signal = ''
    if r['can_long'] == True and r['MACDh'] < 0 and r['after_min_MACDh'] == True and r['after_negative_MACDh_series'] == True and r["Close"] > r["prev_Open"] and r["Close"] - r["prev_Low"] < 5:
        signal = 'long'
    elif r['can_short'] == True and r['MACDh'] > 0 and r['after_max_MACDh'] == True and r['after_positive_MACDh_series'] == True and r["Close"] < r["prev_Open"] and r["prev_High"] - r["Close"] < 5:
        signal = 'short'
    return signal

def prepare_data(df):
    macd = ta.macd(df["Close"], fast=12, slow=26, signal=9)
    df = pd.concat([df, macd], axis=1)
    df.rename(columns={'MACD_12_26_9': 'MACD', 'MACDh_12_26_9': 'MACDh', 'MACDs_12_26_9': 'MACDs'}, inplace=True)
    df['is_max_MACDh'] = df['MACDh'] == df['MACDh'].rolling(10).max()
    df['after_max_MACDh'] = df['is_max_MACDh'].shift(1)
    df['after_positive_MACDh_series'] = df['MACDh'].rolling(5).sum() > 0
    df['is_min_MACDh'] = df['MACDh'] == df['MACDh'].rolling(10).min()
    df['after_negative_MACDh_series'] = df['MACDh'].rolling(5).sum() < 0
    df['after_min_MACDh'] = df['is_min_MACDh'].shift(1)
    df['prev_Open'] = df['Open'].shift(1)
    df['prev_Close'] = df['Close'].shift(1)
    df['prev_High'] = df['High'].shift(1)
    df['prev_Low'] = df['Low'].shift(1)
    df['max_5'] = df['High'].rolling(5).max()
    df['min_5'] = df['Low'].rolling(5).min()
    df = df[(100 * df.index.hour + df.index.minute != 1130) & (100 * df.index.hour + df.index.minute != 1430) & (100 * df.index.hour + df.index.minute != 1445)]
    df['can_short'] = df['Open'].shift(1) < df['Close'].shift(1)
    df['can_long'] = df['Open'].shift(1) > df['Close'].shift(1)
    df['signal'] = df.apply(lambda r: cal_signal(r), axis=1)
    return df

# %%
prepared_data = prepare_data(data)
prepared_data.dropna(inplace=True)

# %%
prepared_data
# Out:
#                        Open    High     Low   Close  Volume      MACD  \
# Date
# 2020-11-02 13:10:00   899.2   900.4   898.9   899.3    1911 -0.247453
# 2020-11-02 13:15:00   899.4   899.4   896.3   896.9    2723 -0.357929
# 2020-11-02 13:20:00   896.9   897.5   896.4   897.4    2973 -0.400520
# 2020-11-02 13:25:00   897.4   898.5   896.4   896.7    2420 -0.485164
# 2020-11-02 13:30:00   896.6   898.4   896.6   898.3    1802 -0.418317
# ...                     ...     ...     ...     ...     ...       ...
# 2025-11-04 14:05:00  1888.7  1891.0  1885.0  1890.2    6530  5.259522
# 2025-11-04 14:10:00  1890.7  1891.0  1885.5  1887.3    5379  5.625271
# 2025-11-04 14:15:00  1887.2  1899.0  1887.2  1898.5   13871  6.741167
# 2025-11-04 14:20:00  1898.2  1907.7  1897.0  1904.2   16090  7.993324
# 2025-11-04 14:25:00  1904.1  1907.4  1900.3  1902.7    9901  8.763608
#
#                         MACDh     MACDs  is_max_MACDh after_max_MACDh  ...  \
# Date                                                                   ...
# 2020-11-02 13:10:00  0.295880 -0.543333         False           False  ...
# 2020-11-02 13:15:00  0.148323 -0.506252         False           False  ...
# 2020-11-02 13:20:00  0.084586 -0.485106         False           False  ...
# 2020-11-02 13:25:00 -0.000047 -0.485117         False           False  ...
# 2020-11-02 13:30:00  0.053440 -0.471757         False           False  ...
# ...                       ...       ...           ...             ...  ...
# 2025-11-04 14:05:00  3.931846  1.327676         False            True  ...
# 2025-11-04 14:10:00  3.438075  2.187195         False           False  ...
# 2025-11-04 14:15:00  3.643178  3.097990         False           False  ...
# 2025-11-04 14:20:00  3.916267  4.077057         False           False  ...
# 2025-11-04 14:25:00  3.749241  5.014367         False           False  ...
#
#                      after_min_MACDh  prev_Open  prev_Close prev_High  \
# Date
# 2020-11-02 13:10:00            False      898.6       899.4     899.7
# 2020-11-02 13:15:00            False      899.2       899.3     900.4
# 2020-11-02 13:20:00            False      899.4       896.9     899.4
# 2020-11-02 13:25:00            False      896.9       897.4     897.5
# 2020-11-02 13:30:00            False      897.4       896.7     898.5
# ...                              ...        ...         ...       ...
# 2025-11-04 14:05:00            False     1887.9      1889.8    1892.0
# 2025-11-04 14:10:00            False     1888.7      1890.2    1891.0
# 2025-11-04 14:15:00            False     1890.7      1887.3    1891.0
# 2025-11-04 14:20:00            False     1887.2      1898.5    1899.0
# 2025-11-04 14:25:00            False     1898.2      1904.2    1907.7
#
#                      prev_Low   max_5   min_5  can_short  can_long  signal
# Date
# 2020-11-02 13:10:00     898.0   900.4   897.1       True     False
# 2020-11-02 13:15:00     898.9   900.4   896.3       True     False
# 2020-11-02 13:20:00     896.3   900.4   896.3      False      True
# 2020-11-02 13:25:00     896.4   900.4   896.3       True     False
# 2020-11-02 13:30:00     896.4   900.4   896.3      False      True
# ...                       ...     ...     ...        ...       ...     ...
# 2025-11-04 14:05:00    1884.0  1899.0  1871.0       True     False
# 2025-11-04 14:10:00    1885.0  1899.0  1883.0       True     False
# 2025-11-04 14:15:00    1885.5  1899.0  1883.0      False      True
# 2025-11-04 14:20:00    1887.2  1907.7  1884.0       True     False
# 2025-11-04 14:25:00    1897.0  1907.7  1885.0       True     False
#
# [59936 rows x 23 columns]

# %%
class MainStrategy(Strategy):
    SL = 0.0032
    RR = 2
    trailing_sl = 4.5
    def init(self):
        self._broker._cash = 2500
        super().init()

    def next(self):
        super().next()
        _time = self.data.index
        current_time = _time[-1]
        if current_time.hour == 14 and current_time.minute >= 25:
            if self.position.is_long or self.position.is_short:
                self.position.close()
            return

        signal = self.data.signal[-1]
        close_price = self.data.Close[-1]
        open_price = self.data.Open[-1]
        #
        # if self.position.is_long:
        #     max_5 = self.data.max_5[-1]
        #     if close_price < max_5 - self.trailing_sl:
        #         self.position.close()
        # elif self.position.is_short:
        #     min_5 = self.data.min_5[-1]
        #     if close_price > min_5 + self.trailing_sl:
        #         self.position.close()
        #
        if self.position:
            return
            if self.position.is_short:
                if self.data.MACDh[-1] > self.data.MACDh[-2]:
                    self.position.close()
            elif self.position.is_long:
                if self.data.MACDh[-1] < self.data.MACDh[-2]:
                    self.position.close()
        #
        if not self.position:
            if signal == 'long':
                buy_price = close_price
                sl = buy_price - (buy_price * self.SL)
                tp = buy_price + (buy_price * self.SL) * self.RR
                self.buy(size=1, sl=sl, tp=tp)
            elif signal == 'short':
                sell_price = close_price
                sl = sell_price + (sell_price * self.SL)
                tp = sell_price - (sell_price * self.SL) * self.RR
                self.sell(size=1, sl=sl, tp=tp)

# %%
bt = Backtest(prepared_data, MainStrategy, exclusive_orders=True)
stats = bt.run()

# %%
stats
# Out:
# Start                     2020-11-02 13:10:00
# End                       2025-11-04 14:25:00
# Duration                   1828 days 01:15:00
# Exposure Time [%]                    37.52169
# Equity Final [$]                   2726.23648
# Equity Peak [$]                    2726.23648
# Return [%]                            9.04946
# Buy & Hold Return [%]               111.57567
# Return (Ann.) [%]                     1.76183
# Volatility (Ann.) [%]                 4.31906
# CAGR [%]                              1.20139
# Sharpe Ratio                          0.40792
# Sortino Ratio                         0.63329
# Calmar Ratio                           0.2089
# Alpha [%]                              9.3301
# Beta                                 -0.00252
# Max. Drawdown [%]                    -8.43392
# Avg. Drawdown [%]                    -0.33476
# Max. Drawdown Duration     1051 days 02:45:00
# Avg. Drawdown Duration       17 days 20:29:00
# # Trades                                 1593
# Win Rate [%]                         37.72756
# Best Trade [%]                        2.10255
# Worst Trade [%]                      -1.86941
# Avg. Trade [%]                        0.01071
# Max. Trade Duration           9 days 23:55:00
# Avg. Trade Duration           0 days 08:08:00
# Profit Factor                         1.05839
# Expectancy [%]                        0.01178
# SQN                                   0.94231
# Kelly Criterion                        0.0188
# _strategy                        MainStrategy
# _equity_curve                             ...
# _trades                         Size  Entr...
# dtype: object

# %%
stats['_trades']
# Out:
#       Size  EntryBar  ExitBar  EntryPrice   ExitPrice          SL          TP  \
# 0        1        30       55       908.1   905.29376   905.29376   914.01248
# 1        1        75       85       908.1   914.01248   905.29376   914.01248
# 2       -1        87      105       913.0   916.02192   916.02192   907.25616
# 3       -1       110      112       915.2   913.70000   917.92800   909.14400
# 4       -1       128      137       915.7   918.63024   918.63024   909.83952
# ...    ...       ...      ...         ...         ...         ...         ...
# 1588     1     59735    59742      1957.6  1951.23600  1951.23600  1970.02800
# 1589    -1     59793    59803      1924.1  1911.68640  1930.15680  1911.68640
# 1590    -1     59816    59825      1905.0  1911.09600  1911.09600  1892.80800
# 1591    -1     59871    59874      1907.8  1895.59008  1913.90496  1895.59008
# 1592     1     59889    59895      1861.0  1873.11168  1855.24416  1873.11168
#
#            PnL  Commission  ReturnPct           EntryTime            ExitTime  \
# 0     -2.80624         0.0  -0.003090 2020-11-03 10:10:00 2020-11-03 13:45:00
# 1      5.91248         0.0   0.006511 2020-11-04 09:55:00 2020-11-04 10:45:00
# 2     -3.02192         0.0  -0.003310 2020-11-04 10:55:00 2020-11-04 13:55:00
# 3      1.50000         0.0   0.001639 2020-11-04 14:20:00 2020-11-05 09:00:00
# 4     -2.93024         0.0  -0.003200 2020-11-05 10:20:00 2020-11-05 11:05:00
# ...        ...         ...        ...                 ...                 ...
# 1588  -6.36400         0.0  -0.003251 2025-10-29 13:45:00 2025-10-29 14:20:00
# 1589  12.41360         0.0   0.006452 2025-10-31 09:05:00 2025-10-31 09:55:00
# 1590  -6.09600         0.0  -0.003200 2025-10-31 11:00:00 2025-10-31 13:15:00
# 1591  12.20992         0.0   0.006400 2025-11-03 13:05:00 2025-11-03 13:20:00
# 1592  12.11168         0.0   0.006508 2025-11-04 09:05:00 2025-11-04 09:35:00
#
#             Duration   Tag
# 0    0 days 03:35:00  None
# 1    0 days 00:50:00  None
# 2    0 days 03:00:00  None
# 3    0 days 18:40:00  None
# 4    0 days 00:45:00  None
# ...              ...   ...
# 1588 0 days 00:35:00  None
# 1589 0 days 00:50:00  None
# 1590 0 days 02:15:00  None
# 1591 0 days 00:15:00  None
# 1592 0 days 00:30:00  None
#
# [1593 rows x 14 columns]

# %%
# bt.plot()

# %%
copy_trades = stats['_trades'].copy()
copy_trades['cum_sum'] = copy_trades['PnL'].cumsum()
X = np.array(range(0, len(copy_trades['cum_sum'])))
Y = copy_trades['cum_sum']
# Plotting the Graph
plt.plot(X, Y)
plt.title("Curve plotted for returns")
plt.xlabel("X")
plt.ylabel("Rerurns")
plt.show()
