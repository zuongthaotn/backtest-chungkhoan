# %% [markdown]
# # Price Action Strategy - by ChatGPT - Backtesting

# %% [markdown]
# ## Import Library

# %%
import warnings
warnings.filterwarnings('ignore')
#
import numpy as np
import pandas as pd
import numpy as np
import pandas_ta as ta
from backtesting.backtesting import Backtest, Strategy
# from backtesting._plotting import set_bokeh_output
# set_bokeh_output(notebook=False)

import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [12, 6]
plt.rcParams['figure.dpi'] = 120
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="bbdba103-0a37-46ae-a5c4-300260ce70e3">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ## Load Price Data

# %%
import os
from pathlib import Path
notebook_path = os.getcwd()
current_dir = Path(notebook_path)
csv_file = str(current_dir.parent) + '/VN30F1M/VN30F1M_5minutes.csv'
is_file = os.path.isfile(csv_file)
if is_file:
    dataset = pd.read_csv(csv_file, index_col='Date', parse_dates=True)
else:
    print(csv_file)
    print('remote')
    dataset = pd.read_csv("https://raw.githubusercontent.com/zuongthaotn/vn-stock-data/main/VN30ps/VN30F1M_5minutes.csv", index_col='Date', parse_dates=True)

# %%
data = dataset.copy()

# %%
data = data[data.index > '2024-11-01 00:00:00']

# %%
# Hàm tìm Demand Zone (nến xanh có khối lượng cao nhất trong 100 nến)
def find_demand_zone(df, window=100):
    demand_zones = []
    for i in range(window, len(df)):
        sub_df = df[i-window:i]
        max_idx = sub_df[sub_df['Close'] > sub_df['Open']]['Volume'].idxmax()
        if pd.notna(max_idx):
            demand_zones.append(df.loc[max_idx, ['Low', 'High']])
    return pd.DataFrame(demand_zones)

# Hàm tìm Supply Zone (nến đỏ có khối lượng cao nhất trong 100 nến)
def find_supply_zone(df, window=100):
    supply_zones = []
    for i in range(window, len(df)):
        sub_df = df[i-window:i]
        max_idx = sub_df[sub_df['Close'] < sub_df['Open']]['Volume'].idxmax()
        if pd.notna(max_idx):
            supply_zones.append(df.loc[max_idx, ['Low', 'High']])
    return pd.DataFrame(supply_zones)

# Hàm nhận diện mô hình nến đảo chiều
def detect_reversal_patterns(df):
    signals = []
    for i in range(2, len(df)):
        if (df['Close'][i] > df['Open'][i] and df['Close'][i-1] < df['Open'][i-1] and
            df['Close'][i] > df['Open'][i-1] and df['Open'][i] < df['Close'][i-1]):
            signals.append(('Bullish Engulfing', i))
        elif (df['Close'][i] < df['Open'][i] and df['Close'][i-1] > df['Open'][i-1] and
              df['Close'][i] < df['Open'][i-1] and df['Open'][i] > df['Close'][i-1]):
            signals.append(('Bearish Engulfing', i))
        elif (df['Close'][i-1] < df['Open'][i-1] and df['Close'][i] > df['Open'][i] and
              df['Close'][i] >= (df['Open'][i-1] + df['Close'][i-1]) / 2):
            signals.append(('Piercing Line', i))
        elif (df['Close'][i-1] > df['Open'][i-1] and df['Close'][i] < df['Open'][i] and
              df['Close'][i] <= (df['Open'][i-1] + df['Close'][i-1]) / 2):
            signals.append(('Dark Cloud Cover', i))
        elif (df['Close'][i-2] > df['Open'][i-2] and df['Close'][i-1] < df['Open'][i-1] and
              df['Close'][i] < df['Open'][i] and df['Close'][i] < df['Close'][i-2]):
            signals.append(('Evening Star', i))
        elif (df['Close'][i-2] < df['Open'][i-2] and df['Close'][i-1] > df['Open'][i-1] and
              df['Close'][i] > df['Open'][i] and df['Close'][i] > df['Close'][i-2]):
            signals.append(('Morning Star', i))
    return signals

# Hàm xác định tín hiệu giao dịch
def find_signals(df, demand_zones, supply_zones, reversal_patterns):
    signals = []
    for pattern, i in reversal_patterns:
        price = df['Close'][i]
        if any(df['Low'][i] >= dz['Low'] and df['High'][i] <= dz['High'] for _, dz in demand_zones.iterrows()):
            if pattern in ['Bullish Engulfing', 'Piercing Line', 'Morning Star']:
                signals.append(('Long', i))
        if any(df['Low'][i] >= sz['Low'] and df['High'][i] <= sz['High'] for _, sz in supply_zones.iterrows()):
            if pattern in ['Bearish Engulfing', 'Dark Cloud Cover', 'Evening Star']:
                signals.append(('Short', i))
    return signals

# %%
demand_zones = find_demand_zone(data)

# %%
demand_zones
# Out:
#                         Low    High
# 2024-11-04 13:45:00  1319.4  1323.3
# 2024-11-04 13:45:00  1319.4  1323.3
# 2024-11-04 13:45:00  1319.4  1323.3
# 2024-11-04 13:45:00  1319.4  1323.3
# 2024-11-04 13:45:00  1319.4  1323.3
# ...                     ...     ...
# 2025-02-14 09:00:00  1345.2  1348.9
# 2025-02-14 09:00:00  1345.2  1348.9
# 2025-02-14 09:00:00  1345.2  1348.9
# 2025-02-14 09:00:00  1345.2  1348.9
# 2025-02-14 09:00:00  1345.2  1348.9
#
# [3461 rows x 2 columns]

# %%
supply_zones = find_supply_zone(data)

# %%
supply_zones
# Out:
#                         Low    High
# 2024-11-01 14:15:00  1326.6  1331.1
# 2024-11-01 14:15:00  1326.6  1331.1
# 2024-11-01 14:15:00  1326.6  1331.1
# 2024-11-01 14:15:00  1326.6  1331.1
# 2024-11-01 14:15:00  1326.6  1331.1
# ...                     ...     ...
# 2025-02-12 14:25:00  1332.8  1335.8
# 2025-02-14 13:25:00  1342.1  1345.5
# 2025-02-14 13:25:00  1342.1  1345.5
# 2025-02-14 13:25:00  1342.1  1345.5
# 2025-02-14 13:25:00  1342.1  1345.5
#
# [3461 rows x 2 columns]

# %%
reversal_patterns = detect_reversal_patterns(data)

# %%
test_df = find_signals(data, demand_zones, supply_zones, reversal_patterns)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 test_df = find_signals(data, demand_zones, supply_zones, reversal_patterns)
#
# Cell In[5], line 50, in find_signals(df, demand_zones, supply_zones, reversal_patterns)
#      48 for pattern, i in reversal_patterns:
#      49     price = df['Close'][i]
# ---> 50     if any(df['Low'][i] >= dz['Low'] and df['High'][i] <= dz['High'] for _, dz in demand_zones.iterrows()):
#      51         if pattern in ['Bullish Engulfing', 'Piercing Line', 'Morning Star']:
#      52             signals.append(('Long', i))
#
# Cell In[5], line 50, in <genexpr>(.0)
#      48 for pattern, i in reversal_patterns:
#      49     price = df['Close'][i]
# ---> 50     if any(df['Low'][i] >= dz['Low'] and df['High'][i] <= dz['High'] for _, dz in demand_zones.iterrows()):
#      51         if pattern in ['Bullish Engulfing', 'Piercing Line', 'Morning Star']:
#      52             signals.append(('Long', i))
#
# File ~/PycharmProjects/algo-stock/venv/lib/python3.11/site-packages/pandas/core/frame.py:1450, in DataFrame.iterrows(self)
#    1448 using_cow = using_copy_on_write()
#    1449 for k, v in zip(self.index, self.values):
# -> 1450     s = klass(v, index=columns, name=k).__finalize__(self)
#    1451     if using_cow and self._mgr.is_single_block:
#    1452         s._mgr.add_references(self._mgr)  # type: ignore[arg-type]
#
# File ~/PycharmProjects/algo-stock/venv/lib/python3.11/site-packages/pandas/core/series.py:520, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
#     517     elif manager == "array":
#     518         data = SingleArrayManager.from_array(data, index)
# --> 520 NDFrame.__init__(self, data)
#     521 self.name = name
#     522 self._set_axis(0, index)
#
# File ~/PycharmProjects/algo-stock/venv/lib/python3.11/site-packages/pandas/core/generic.py:279, in NDFrame.__init__(self, data)
#     277 object.__setattr__(self, "_item_cache", {})
#     278 object.__setattr__(self, "_attrs", {})
# --> 279 object.__setattr__(self, "_flags", Flags(self, allows_duplicate_labels=True))
#
# File ~/PycharmProjects/algo-stock/venv/lib/python3.11/site-packages/pandas/core/flags.py:55, in Flags.__init__(self, obj, allows_duplicate_labels)
#      53 def __init__(self, obj: NDFrame, *, allows_duplicate_labels: bool) -> None:
#      54     self._allows_duplicate_labels = allows_duplicate_labels
# ---> 55     self._obj = weakref.ref(obj)
#
# KeyboardInterrupt:

# %%
test_df

# %%
# Chiến lược giao dịch dựa trên Price Action
class PriceActionStrategy(Strategy):
    def init(self):
        pass
    
    def next(self):
        df = self.data.df
        demand_zones = find_demand_zone(df)
        supply_zones = find_supply_zone(df)
        reversal_patterns = detect_reversal_patterns(df)
        signals = find_signals(df, demand_zones, supply_zones, reversal_patterns)
        
        for signal, i in signals:
            price = self.data.Close[i]
            if signal == 'Long':
                sl = min(self.data.Low[i-1], self.data.Low[i])
                tp = price + 3 * (price - sl)
                self.buy(sl=sl, tp=tp)
            elif signal == 'Short':
                sl = max(self.data.High[i-1], self.data.High[i])
                tp = price - 3 * (sl - price)
                self.sell(sl=sl, tp=tp)

# %%
# Chạy Backtest
bt = Backtest(data, PriceActionStrategy, cash=10000, commission=.002)
stats = bt.run()
bt.plot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 3
#       1 # Chạy Backtest
#       2 bt = Backtest(data, PriceActionStrategy, cash=10000, commission=.002)
# ----> 3 stats = bt.run()
#       4 bt.plot()
#
# File ~/PycharmProjects/algo-stock/venv/lib/python3.11/site-packages/backtesting/backtesting.py:1219, in Backtest.run(self, **kwargs)
#    1216         break
#    1218     # Next tick, a moment before bar close
# -> 1219     strategy.next()
#    1220 else:
#    1221     # Close any remaining open trades so they produce some stats
#    1222     for trade in broker.trades:
#
# Cell In[13], line 8, in PriceActionStrategy.next(self)
#       6 def next(self):
#       7     df = self.data.df
# ----> 8     demand_zones = find_demand_zone(df)
#       9     supply_zones = find_supply_zone(df)
#      10     reversal_patterns = detect_reversal_patterns(df)
#
# Cell In[12], line 3, in find_demand_zone(df, window)
#       2 def find_demand_zone(df, window=100):
# ----> 3     max_idx = df[df['Close'] > df['Open']]['Volume'].rolling(window).idxmax()
#       4     return df.loc[max_idx.dropna().astype(int), ['Low', 'High']]
#
# File ~/PycharmProjects/algo-stock/venv/lib/python3.11/site-packages/pandas/core/window/rolling.py:320, in BaseWindow.__getattr__(self, attr)
#     317 if attr in self.obj:
#     318     return self[attr]
# --> 320 raise AttributeError(
#     321     f"'{type(self).__name__}' object has no attribute '{attr}'"
#     322 )
#
# AttributeError: 'Rolling' object has no attribute 'idxmax'
